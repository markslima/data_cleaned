# %%
"""
Sales data analysis with python & pandas, data cleaning and transformation

Mark Slima
"""

# %% [markdown]
# ##### Import pandas library, read sales .csv data into python and assign to variable

# %%
import pandas as pd

# %%
data = pd.read_csv('transaction.csv', sep=';')
data.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# dtypes: float64(2), int64(6), object(5)
# ...

# %%
data.shape
# Out:
# (1047588, 13)

# %% [markdown]
# ##### High level overview of dataset, including Count, Mean, Mode, Standard Deviation Min/Max, and Quartile information

# %%
data.describe()
# Out:
#              UserId  TransactionId          Year           Day      ItemCode  \
# count  1.047588e+06   1.047588e+06  1.047588e+06  1.047588e+06  1.047588e+06
# mean   2.410198e+05   6.159421e+06  2.018301e+03  1.601806e+01  6.582370e+05
# std    1.423365e+05   1.476295e+05  8.386806e-01  8.703711e+00  4.526359e+05
# min   -1.000000e+00   5.900015e+06  2.018000e+03  1.000000e+00 -1.000000e+00
# 25%    2.593920e+05   6.026856e+06  2.018000e+03  9.000000e+00  4.609290e+05
# 50%    3.020220e+05   6.166622e+06  2.018000e+03  1.700000e+01  4.752930e+05
# 75%    3.413550e+05   6.289250e+06  2.019000e+03  2.300000e+01  4.889430e+05
# max    3.840270e+05   6.397457e+06  2.028000e+03  3.100000e+01  1.894494e+06
#
#        NumberOfItemsPurchased   CostPerItem  SellingPricePerItem
# count            1.047588e+06  1.047588e+06         1.047588e+06
# mean             2.868132e+01  9.635369e+00         1.461392e+01
# std              6.643064e+02  2.347699e+03         3.888521e+03
# ...

# %%
#CostPerTrancaction = CostPerItem * NumberOfItemsPurchased

# %%
CostPerItem = data['CostPerItem']

# %%
NumberOfItemsPurchased = data['NumberOfItemsPurchased']

# %%
CostPerTransaction = CostPerItem * NumberOfItemsPurchased

# %%
CostPerTransaction
# Out:
# 0          70.38
# 1          10.56
# 2          64.80
# 3           5.19
# 4          10.20
#            ...
# 1047583    15.54
# 1047584    57.60
# 1047585    34.20
# 1047586     8.64
# 1047587    20.40
# Length: 1047588, dtype: float64

# %% [markdown]
# ##### Creation of new Series to reflect Cost Per Transaction

# %%
data['CostPerTransaction'] = CostPerTransaction

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# ...

# %%
data.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
data['SalesPerTransaction'] = data['SellingPricePerItem'] * data['NumberOfItemsPurchased']

# %%
data['ProfitPerTransaction'] = data['SalesPerTransaction'] - data['CostPerTransaction']

# %%
data['Markup'] = (data['SalesPerTransaction'] - data['CostPerTransaction']) / data['CostPerTransaction']

# %%
data['Markup'].head()
# Out:
# 0    0.799659
# 1    0.099432
# 2    0.800000
# 3    0.098266
# 4    0.700000
# Name: Markup, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# ...

# %%
rounded_markup = round(data['Markup'], 2)

# %%
rounded_markup.head()
# Out:
# 0    0.8
# 1    0.1
# 2    0.8
# 3    0.1
# 4    0.7
# Name: Markup, dtype: float64

# %%
data
# Out:
#          UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0        278166        6355745  2019   Feb    2  12:50:00    465549
# 1        337701        6283376  2018   Dec   26  09:06:00    482370
# 2        267099        6385599  2019   Feb   15  09:45:00    490728
# 3        380478        6044973  2018   Jun   22  07:14:00    459186
# 4            -1        6143225  2018   Sep   10  11:58:00   1733592
# ...         ...            ...   ...   ...  ...       ...       ...
# 1047583  343560        6386952  2019   Feb   16  08:16:00    450030
# 1047584  276528        6316717  2019   Jan   15  08:56:00   1732143
# 1047585  341082        6140585  2018   Sep    8  10:41:00    487326
# 1047586  336147        6075190  2018   Jul   20  09:32:00    460509
# 1047587      -1        6180020  2018   Oct   10  12:00:00    473739
#
#                             ItemDescription  NumberOfItemsPurchased  \
# 0          FAMILY ALBUM WHITE PICTURE FRAME                       6
# ...

# %%
data['Markup'] = round(data['Markup'],2)

# %%
data.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %% [markdown]
# Conversion of day/year fields into String datatype, to prep for conversion into DATE Series

# %%
day = data['Day'].astype(str)

# %%
year = data['Year'].astype(str)

# %%
my_date = day + '-' + data['Month'] + '-' + year

# %%
my_date
# Out:
# 0           2-Feb-2019
# 1          26-Dec-2018
# 2          15-Feb-2019
# 3          22-Jun-2018
# 4          10-Sep-2018
#               ...
# 1047583    16-Feb-2019
# 1047584    15-Jan-2019
# 1047585     8-Sep-2018
# 1047586    20-Jul-2018
# 1047587    10-Oct-2018
# Length: 1047588, dtype: object

# %%
data['date'] = my_date

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# ...

# %%
data.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
data.iloc[0][7]
# Out:
# 'FAMILY ALBUM WHITE PICTURE FRAME'

# %%
data.iloc[0:3]
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
#
#                                       ClientKeywords  CostPerTransaction  \
# 0  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...               70.38
# 1   ['Middle Age', 'Corporation', '2-5 Year Client']               10.56
# ...

# %%
data.iloc[-5:, 7]
# Out:
# 1047583    SET/3 RED GINGHAM ROSE STORAGE BOX
# 1047584    WOOD 2 DRAWER CABINET WHITE FINISH
# 1047585                LUNCH BAG APPLE DESIGN
# 1047586        JUMBO BAG PINK VINTAGE PAISLEY
# 1047587                   SEASIDE FLYING DISC
# Name: ItemDescription, dtype: object

# %% [markdown]
# ##### Use .str.split() to split a Series containing multiple strings, each to their own discreet Series

# %%
split_col = data['ClientKeywords'].str.split(',', expand=True)

# %%
split_col[0]
# Out:
# 0               ['Senior'
# 1           ['Middle Age'
# 2           ['Middle Age'
# 3           ['Middle Age'
# 4           ['Middle Age'
#                 ...
# 1047583     ['Middle Age'
# 1047584     ['Middle Age'
# 1047585    ['Young Adult'
# 1047586         ['Senior'
# 1047587     ['Middle Age'
# Name: 0, Length: 1047588, dtype: object

# %%
split_col[1]
# Out:
# 0           'Solo Entrepreneur'
# 1                 'Corporation'
# 2                 'Corporation'
# 3              'Small Business'
# 4           'Solo Entrepreneur'
#                    ...
# 1047583           'Corporation'
# 1047584        'Small Business'
# 1047585           'Corporation'
# 1047586     'Solo Entrepreneur'
# 1047587     'Solo Entrepreneur'
# Name: 1, Length: 1047588, dtype: object

# %%
split_col[2]
# Out:
# 0           '2-5 Year Client']
# 1           '2-5 Year Client']
# 2           '2-5 Year Client']
# 3                'New Client']
# 4           '2-5 Year Client']
#                   ...
# 1047583          'New Client']
# 1047584        'Loyal Client']
# 1047585          'New Client']
# 1047586        'Loyal Client']
# 1047587     '2-5 Year Client']
# Name: 2, Length: 1047588, dtype: object

# %%
client_type = split_col[2]

# %%
client_type
# Out:
# 0           '2-5 Year Client']
# 1           '2-5 Year Client']
# 2           '2-5 Year Client']
# 3                'New Client']
# 4           '2-5 Year Client']
#                   ...
# 1047583          'New Client']
# 1047584        'Loyal Client']
# 1047585          'New Client']
# 1047586        'Loyal Client']
# 1047587     '2-5 Year Client']
# Name: 2, Length: 1047588, dtype: object

# %% [markdown]
# ##### Split 'ClientKeywords' column into three separate columns

# %%
split_col = data['ClientKeywords'].str.split(',', expand=True)
data['ClientAge'] = split_col[0]
data['ClientType'] = split_col[1]
data['LengthOfContract'] = split_col[2]

# %%
data.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    ...         Country                                     ClientKeywords  \
# ...

# %% [markdown]
# #### Clean extra bracket symbols with str.replace() method

# %%
data['ClientAge'] = data['ClientAge'].str.replace('[', '')
# Out:
# /var/folders/14/02fbvt013wg696nxdq9byg180000gn/T/ipykernel_13953/993674171.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['ClientAge'] = data['ClientAge'].str.replace('[', '')

# %%
data['ClientAge']
# Out:
# 0               'Senior'
# 1           'Middle Age'
# 2           'Middle Age'
# 3           'Middle Age'
# 4           'Middle Age'
#                ...
# 1047583     'Middle Age'
# 1047584     'Middle Age'
# 1047585    'Young Adult'
# 1047586         'Senior'
# 1047587     'Middle Age'
# Name: ClientAge, Length: 1047588, dtype: object

# %%
data['LengthOfContract'] = data['LengthOfContract'].str.replace(']', '')
# Out:
# /var/folders/14/02fbvt013wg696nxdq9byg180000gn/T/ipykernel_13953/809684684.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['LengthOfContract'] = data['LengthOfContract'].str.replace(']', '')

# %%
data['LengthOfContract']
# Out:
# 0           '2-5 Year Client'
# 1           '2-5 Year Client'
# 2           '2-5 Year Client'
# 3                'New Client'
# 4           '2-5 Year Client'
#                   ...
# 1047583          'New Client'
# 1047584        'Loyal Client'
# 1047585          'New Client'
# 1047586        'Loyal Client'
# 1047587     '2-5 Year Client'
# Name: LengthOfContract, Length: 1047588, dtype: object

# %% [markdown]
# #### use .str.lower() to set all text to lowercase

# %%
data['ItemDescription']
# Out:
# 0            FAMILY ALBUM WHITE PICTURE FRAME
# 1                       LONDON BUS COFFEE MUG
# 2           SET 12 COLOUR PENCILS DOLLY GIRL
# 3                 UNION JACK FLAG LUGGAGE TAG
# 4                         WASHROOM METAL SIGN
#                           ...
# 1047583    SET/3 RED GINGHAM ROSE STORAGE BOX
# 1047584    WOOD 2 DRAWER CABINET WHITE FINISH
# 1047585                LUNCH BAG APPLE DESIGN
# 1047586        JUMBO BAG PINK VINTAGE PAISLEY
# 1047587                   SEASIDE FLYING DISC
# Name: ItemDescription, Length: 1047588, dtype: object

# %%
data['ItemDescription'] = data['ItemDescription'].str.lower()

# %%
data['ItemDescription']
# Out:
# 0            family album white picture frame
# 1                       london bus coffee mug
# 2           set 12 colour pencils dolly girl
# 3                 union jack flag luggage tag
# 4                         washroom metal sign
#                           ...
# 1047583    set/3 red gingham rose storage box
# 1047584    wood 2 drawer cabinet white finish
# 1047585                lunch bag apple design
# 1047586        jumbo bag pink vintage paisley
# 1047587                   seaside flying disc
# Name: ItemDescription, Length: 1047588, dtype: object

# %%
#### bringing in a new dataset by mergeing two files

# %%
seasons = pd.read_csv('./value_inc_seasons.csv', sep=';')

# %%
seasons
# Out:
#    Month Season
# 0    Jan   High
# 1    Feb    Mid
# 2    Mar    Low
# 3    Apr    Low
# 4    May    Low
# 5    Jun   High
# 6    Jul   High
# 7    Aug   High
# 8    Sep    Mid
# 9    Oct    Low
# 10   Nov    Low
# 11   Dec   High

# %%
# merging files: merg_df = pd.merge(df_old, df_new, on = 'key')

# %% [markdown]
# ##### merge two datasets using .merge() function with key common to both datasets

# %%
data = pd.merge(data, seasons, on = 'Month')

# %%
data
# Out:
#          UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0        278166        6355745  2019   Feb    2  12:50:00    465549
# 1        267099        6385599  2019   Feb   15  09:45:00    490728
# 2        328440        6387425  2019   Feb   16  10:35:00    494802
# 3        364791        6358242  2019   Feb    3  09:25:00    486276
# 4            -1        6388019  2019   Feb   16  13:24:00    490329
# ...         ...            ...   ...   ...  ...       ...       ...
# 1047583  315651        5999719  2018   May   14  10:46:00    480018
# 1047584  300909        6010158  2018   May   23  08:17:00    435771
# 1047585  277830        6000060  2018   May   14  13:33:00    477162
# 1047586      -1        6015801  2018   May   29  14:18:00    476637
# 1047587      -1        6015856  2018   May   29  14:24:00    484071
#
#                              ItemDescription  NumberOfItemsPurchased  \
# 0           family album white picture frame                       6
# ...

# %% [markdown]
# #### use .drop() method to remove Series from DataFrame - remember to set axis=1 so it drops the Series -> default is axis=0, which is a row

# %%
# drop columns
# df = df.drop('column', axis=1)

# %%
data = data.drop('ClientKeywords', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1047588 entries, 0 to 1047587
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  CostPerTransaction      1047588 non-null  float64
# ...

# %% [markdown]
# #### to drop multiple columns with .drop(), enter a list with columns to drop

# %%
data = data.drop(['Year', 'Month', 'Day'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1047588 entries, 0 to 1047587
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Time                    1047588 non-null  object
#  3   ItemCode                1047588 non-null  int64
#  4   ItemDescription         1044797 non-null  object
#  5   NumberOfItemsPurchased  1047588 non-null  int64
#  6   CostPerItem             1047588 non-null  float64
#  7   SellingPricePerItem     1047588 non-null  float64
#  8   Country                 1047588 non-null  object
#  9   CostPerTransaction      1047588 non-null  float64
#  10  SalesPerTransaction     1047588 non-null  float64
#  11  ProfitPerTransaction    1047588 non-null  float64
#  12  Markup                  1042743 non-null  float64
# ...

# %%
data
# Out:
#          UserId  TransactionId      Time  ItemCode  \
# 0        278166        6355745  12:50:00    465549
# 1        267099        6385599  09:45:00    490728
# 2        328440        6387425  10:35:00    494802
# 3        364791        6358242  09:25:00    486276
# 4            -1        6388019  13:24:00    490329
# ...         ...            ...       ...       ...
# 1047583  315651        5999719  10:46:00    480018
# 1047584  300909        6010158  08:17:00    435771
# 1047585  277830        6000060  13:33:00    477162
# 1047586      -1        6015801  14:18:00    476637
# 1047587      -1        6015856  14:24:00    484071
#
#                              ItemDescription  NumberOfItemsPurchased  \
# 0           family album white picture frame                       6
# 1          set 12 colour pencils dolly girl                       72
# 2        set of 6 ribbons perfectly pretty                        36
# 3              set of 5 mini grocery magnets                       3
# ...

# %% [markdown]
# #### export this dataset to a .csv using the .to_csv() method

# %%
data.to_csv('valueinc_cleaned.csv', index = False)
